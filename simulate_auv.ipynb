# %%
# simulate_auv.py
import json
import numpy as np
from clustering import cluster_split, choose_cluster_head
from select_path_greedy import compute_travel_time, path_selection

def simulate_auv_cycle(data, r_sen=100, R=20, E_tx=5, E_rx=2, v_AUV=10, death_threshold=0.9):
    
    positions = np.array([[d["x"], d["y"], d["z"]] for d in data])
    energies = {d["id"]: d["energy_node"] for d in data}
    node_ids = [d["id"] for d in data]
    total_nodes = len(node_ids)
    cycle = 0
    total_travel_time = 0.0

    while True:
        alive_ids = [nid for nid, e in energies.items() if e > 0] # chỉ xét các node còn sống
        alive_count = len(alive_ids)
        dead_count = total_nodes - alive_count
        dead_ratio = dead_count / total_nodes

        # điều kiện dừng
        if dead_ratio >= death_threshold:
            print(f"\nMạng sập: {dead_count}/{total_nodes} nodes chết ({dead_ratio*100:.1f}%)")
            break

        cycle += 1
        print(f"\nChu kỳ {cycle}: {alive_count}/{total_nodes} nodes hoạt động")

        # lấy pos của nodes còn sống
        alive_positions = np.array([positions[nid] for nid in alive_ids])

        # phân cụm các node còn sống (trả về danh sách cụm)
        clusters_raw = cluster_split(alive_positions, alive_ids, r_sen=r_sen, R=R)
        cluster_heads = []
        positions_dict = {}

        for c in clusters_raw:
            ch = choose_cluster_head(c, energies)
            cluster_heads.append(ch)
            # dùng tâm cụm để tính khoảng cách 
            positions_dict[ch] = np.mean(c["nodes"], axis=0)

        # nếu không có cluster head (quá ít node), dừng
        if len(cluster_heads) == 0:
            print("Không còn cluster head nào — dừng mô phỏng.")
            break

        # tính ma trận thời gian di chuyển và tìm đường
        travel_time = compute_travel_time(cluster_heads, positions_dict, v_AUV)
        best_path, best_time = path_selection(cluster_heads, travel_time, positions, v_AUV)

        # tạo danh sách chi tiết các segment
        O = np.array([0, 0, 0])
        segment_times = []

        # Từ O đến nút đầu tiên
        first_ch = cluster_heads[best_path[0]]
        start_dist = np.linalg.norm(positions_dict[first_ch] - O)
        start_time = start_dist / v_AUV
        segment_times.append((f"O → {first_ch}", start_time))

        # giữa các CH
        for i in range(1, len(best_path)):
            from_idx = cluster_heads[best_path[i-1]]
            to_idx = cluster_heads[best_path[i]]
            seg_time = travel_time[best_path[i-1]][best_path[i]]
            segment_times.append((f"{from_idx} → {to_idx}", seg_time))

        # nút cuối về O
        last_ch = cluster_heads[best_path[-1]]
        end_dist = np.linalg.norm(positions_dict[last_ch] - O)
        end_time = end_dist / v_AUV
        segment_times.append((f"{last_ch} → O", end_time))

        # tổng thời gian 
        cycle_time = best_time + start_time + end_time
        total_travel_time += cycle_time
        

    
        print("\nĐường đi tối ưu chi tiết (theo thứ tự thăm của AUV):")
        path_ids = [cluster_heads[i] for i in best_path]
        for idx, node_id in enumerate(path_ids, start=1):
            pos = positions_dict[node_id]
            print(f"  {idx:02d}. Node ID: {node_id:<3}  | Tọa độ: ({pos[0]:.2f}, {pos[1]:.2f}, {pos[2]:.2f})")
        print("về O(0, 0, 0)")
        print("\nThời gian từng chặng trong chu kỳ:")
        for idx, (seg_desc, t) in enumerate(segment_times, start=1):
            print(f"  {idx:02d}. {seg_desc:<20} → {t:.2f} s")
        print(f"Tổng thời gian chu kỳ {cycle}: {cycle_time:.2f} s")

        # cập nhật năng lượng cho các node
        for c in clusters_raw:
            ch = choose_cluster_head(c, energies)
            energies[ch] -= E_tx
            if energies[ch] < 0:
                energies[ch] = 0
            for nid in c["node_ids"]:
                if nid != ch:
                    energies[nid] -= E_rx
                    if energies[nid] < 0:
                        energies[nid] = 0

        # in trạng thái tóm tắt
        alive_count_after = len([e for e in energies.values() if e > 0])
        dead_count_after = total_nodes - alive_count_after
        print(f"Sau cập nhật năng lượng: {alive_count_after} nodes sống, {dead_count_after} nodes chết")

        # kiểm tra điều kiện dừng
        if (total_nodes - alive_count_after) / total_nodes >= death_threshold:
            print(f"\nMạng sập sau cập nhật: {(total_nodes - alive_count_after)}/{total_nodes} nodes chết")
            break

    print(f"\nTổng số chu kỳ hoàn thành: {cycle}")
    print(f"Tổng thời gian di chuyển của AUV: {total_travel_time:.2f} s")
    return cycle, total_travel_time


# chạy mô phỏng 
if __name__ == "__main__":
    with open("input_data/nodes_100.json", "r") as f:
        data = json.load(f)
    simulate_auv_cycle(data)
# Out:
# Chu kỳ 1: 100/100 nodes hoạt động
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#   File "c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\subprocess.py", line 503, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\subprocess.py", line 1456, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 51   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 51              → 5.20 s
#   03. 51 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 10              → 6.01 s
#   07. 10 → 74              → 3.56 s
#   08. 74 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 1: 59.77 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 2: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 51   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 51              → 5.20 s
#   03. 51 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 10              → 6.01 s
#   07. 10 → 74              → 3.56 s
#   08. 74 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 2: 59.77 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 3: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 51   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 51              → 5.20 s
#   03. 51 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 10              → 6.01 s
#   07. 10 → 74              → 3.56 s
#   08. 74 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 3: 59.77 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 4: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 20   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 51   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 20               → 7.56 s
#   02. 20 → 51              → 5.20 s
#   03. 51 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 10              → 6.01 s
#   07. 10 → 74              → 3.56 s
#   08. 74 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 4: 59.57 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 5: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 44   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 51   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 44               → 7.56 s
#   02. 44 → 51              → 5.20 s
#   03. 51 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 10              → 6.01 s
#   07. 10 → 74              → 3.56 s
#   08. 74 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 5: 59.30 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 6: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 46   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 73   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 46              → 5.20 s
#   03. 46 → 58              → 4.28 s
#   04. 58 → 76              → 5.50 s
#   05. 76 → 73              → 5.92 s
#   06. 73 → 10              → 6.01 s
#   07. 10 → 30              → 3.56 s
#   08. 30 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 6: 59.77 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 7: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 20   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 51   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 19   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 20               → 7.56 s
#   02. 20 → 51              → 5.20 s
#   03. 51 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 10              → 6.01 s
#   07. 10 → 74              → 3.56 s
#   08. 74 → 19              → 4.71 s
#   09. 19 → O               → 4.51 s
# Tổng thời gian chu kỳ 7: 59.93 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 8: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 42   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 93   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 12   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 36   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 42               → 7.56 s
#   02. 42 → 93              → 5.20 s
#   03. 93 → 58              → 4.28 s
#   04. 58 → 76              → 5.50 s
#   05. 76 → 12              → 5.92 s
#   06. 12 → 36              → 6.01 s
#   07. 36 → 30              → 3.56 s
#   08. 30 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 8: 59.99 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 9: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 44   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 14   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 73   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 36   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 19   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 44               → 7.56 s
#   02. 44 → 14              → 5.20 s
#   03. 14 → 58              → 4.28 s
#   04. 58 → 76              → 5.50 s
#   05. 76 → 73              → 5.92 s
#   06. 73 → 36              → 6.01 s
#   07. 36 → 74              → 3.56 s
#   08. 74 → 19              → 4.71 s
#   09. 19 → O               → 4.51 s
# Tổng thời gian chu kỳ 9: 59.67 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 10: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 42   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 46   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 61   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 26   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 42               → 7.56 s
#   02. 42 → 46              → 5.20 s
#   03. 46 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 61              → 6.01 s
#   07. 61 → 30              → 3.56 s
#   08. 30 → 26              → 4.71 s
#   09. 26 → O               → 4.51 s
# Tổng thời gian chu kỳ 10: 59.01 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 11: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 20   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 22   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 56   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 75   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 12   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 19   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 20               → 7.56 s
#   02. 20 → 22              → 5.20 s
#   03. 22 → 56              → 4.28 s
#   04. 56 → 75              → 5.50 s
#   05. 75 → 12              → 5.92 s
#   06. 12 → 10              → 6.01 s
#   07. 10 → 74              → 3.56 s
#   08. 74 → 19              → 4.71 s
#   09. 19 → O               → 4.51 s
# Tổng thời gian chu kỳ 11: 59.93 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 12: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 38   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 73   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 81   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 26   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 38              → 5.20 s
#   03. 38 → 58              → 4.28 s
#   04. 58 → 76              → 5.50 s
#   05. 76 → 73              → 5.92 s
#   06. 73 → 81              → 6.01 s
#   07. 81 → 30              → 3.56 s
#   08. 30 → 26              → 4.71 s
#   09. 26 → O               → 4.51 s
# Tổng thời gian chu kỳ 12: 58.80 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 13: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 44   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 93   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 56   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 75   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 12   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 36   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 97   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 44               → 7.56 s
#   02. 44 → 93              → 5.20 s
#   03. 93 → 56              → 4.28 s
#   04. 56 → 75              → 5.50 s
#   05. 75 → 12              → 5.92 s
#   06. 12 → 36              → 6.01 s
#   07. 36 → 97              → 3.56 s
#   08. 97 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 13: 59.30 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 14: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 42   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 41   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 13   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 73   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 61   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 78   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 42               → 7.56 s
#   02. 42 → 41              → 5.20 s
#   03. 41 → 13              → 4.28 s
#   04. 13 → 37              → 5.50 s
#   05. 37 → 73              → 5.92 s
#   06. 73 → 61              → 6.01 s
#   07. 61 → 30              → 3.56 s
#   08. 30 → 78              → 4.71 s
#   09. 78 → O               → 4.51 s
# Tổng thời gian chu kỳ 14: 60.54 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 15: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 20   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 14   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 56   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 75   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 95   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 21   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 20               → 7.56 s
#   02. 20 → 14              → 5.20 s
#   03. 14 → 56              → 4.28 s
#   04. 56 → 75              → 5.50 s
#   05. 75 → 84              → 5.92 s
#   06. 84 → 95              → 6.01 s
#   07. 95 → 74              → 3.56 s
#   08. 74 → 21              → 4.71 s
#   09. 21 → O               → 4.51 s
# Tổng thời gian chu kỳ 15: 58.49 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 16: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 1    | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 31   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 54   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 81   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 50   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 19   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 1               → 5.20 s
#   03. 1 → 31               → 4.28 s
#   04. 31 → 76              → 5.50 s
#   05. 76 → 54              → 5.92 s
#   06. 54 → 81              → 6.01 s
#   07. 81 → 50              → 3.56 s
#   08. 50 → 19              → 4.71 s
#   09. 19 → O               → 4.51 s
# Tổng thời gian chu kỳ 16: 60.14 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 17: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 44   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 7    | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 13   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 75   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 12   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 36   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 97   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 26   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 44               → 7.56 s
#   02. 44 → 7               → 5.20 s
#   03. 7 → 13               → 4.28 s
#   04. 13 → 75              → 5.50 s
#   05. 75 → 12              → 5.92 s
#   06. 12 → 36              → 6.01 s
#   07. 36 → 97              → 3.56 s
#   08. 97 → 26              → 4.71 s
#   09. 26 → O               → 4.51 s
# Tổng thời gian chu kỳ 17: 58.33 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 18: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 42   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 22   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 56   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 62   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 61   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 50   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 78   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 42               → 7.56 s
#   02. 42 → 22              → 5.20 s
#   03. 22 → 56              → 4.28 s
#   04. 56 → 37              → 5.50 s
#   05. 37 → 62              → 5.92 s
#   06. 62 → 61              → 6.01 s
#   07. 61 → 50              → 3.56 s
#   08. 50 → 78              → 4.71 s
#   09. 78 → O               → 4.51 s
# Tổng thời gian chu kỳ 18: 60.54 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 19: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 20   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 38   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 31   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 73   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 95   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 97   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 21   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 20               → 7.56 s
#   02. 20 → 38              → 5.20 s
#   03. 38 → 31              → 4.28 s
#   04. 31 → 76              → 5.50 s
#   05. 76 → 73              → 5.92 s
#   06. 73 → 95              → 6.01 s
#   07. 95 → 97              → 3.56 s
#   08. 97 → 21              → 4.71 s
#   09. 21 → O               → 4.51 s
# Tổng thời gian chu kỳ 19: 58.49 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 20: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 68   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 46   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 13   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 75   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 54   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 53   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 65   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 68               → 7.56 s
#   02. 68 → 46              → 5.20 s
#   03. 46 → 13              → 4.28 s
#   04. 13 → 75              → 5.50 s
#   05. 75 → 54              → 5.92 s
#   06. 54 → 53              → 6.01 s
#   07. 53 → 30              → 3.56 s
#   08. 30 → 65              → 4.71 s
#   09. 65 → O               → 4.51 s
# Tổng thời gian chu kỳ 20: 60.06 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 21: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 44   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 32   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 94   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 6    | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 3    | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 8    | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 26   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 44               → 7.56 s
#   02. 44 → 32              → 5.20 s
#   03. 32 → 94              → 4.28 s
#   04. 94 → 76              → 5.50 s
#   05. 76 → 6               → 5.92 s
#   06. 6 → 3                → 6.01 s
#   07. 3 → 8                → 3.56 s
#   08. 8 → 26               → 4.71 s
#   09. 26 → O               → 4.51 s
# Tổng thời gian chu kỳ 21: 58.33 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 22: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 68   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 41   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 31   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 48   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 62   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 23   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 50   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 78   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 68               → 7.56 s
#   02. 68 → 41              → 5.20 s
#   03. 41 → 31              → 4.28 s
#   04. 31 → 48              → 5.50 s
#   05. 48 → 62              → 5.92 s
#   06. 62 → 23              → 6.01 s
#   07. 23 → 50              → 3.56 s
#   08. 50 → 78              → 4.71 s
#   09. 78 → O               → 4.51 s
# Tổng thời gian chu kỳ 22: 60.11 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 23: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 42   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 83   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 80   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 39   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 81   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 97   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 21   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 42               → 7.56 s
#   02. 42 → 83              → 5.20 s
#   03. 83 → 80              → 4.28 s
#   04. 80 → 37              → 5.50 s
#   05. 37 → 39              → 5.92 s
#   06. 39 → 81              → 6.01 s
#   07. 81 → 97              → 3.56 s
#   08. 97 → 21              → 4.71 s
#   09. 21 → O               → 4.51 s
# Tổng thời gian chu kỳ 23: 58.91 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 24: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 8    | Tọa độ: (27.19, 75.45, 16.50)
#   02. Node ID: 53   | Tọa độ: (19.96, 81.90, 50.80)
#   03. Node ID: 45   | Tọa độ: (69.75, 71.21, 82.77)
#   04. Node ID: 75   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 55   | Tọa độ: (72.84, 19.97, 35.58)
#   06. Node ID: 1    | Tọa độ: (66.49, 25.48, 77.55)
#   07. Node ID: 16   | Tọa độ: (15.09, 23.93, 70.10)
#   08. Node ID: 25   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 8                → 8.19 s
#   02. 8 → 53               → 3.56 s
#   03. 53 → 45              → 6.01 s
#   04. 45 → 75              → 5.92 s
#   05. 75 → 55              → 5.50 s
#   06. 55 → 1               → 4.28 s
#   07. 1 → 16               → 5.20 s
#   08. 16 → 25              → 4.93 s
#   09. 25 → O               → 4.51 s
# Tổng thời gian chu kỳ 24: 57.86 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 25: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 72   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 93   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 56   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 48   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 40   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 3    | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 65   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 72               → 7.56 s
#   02. 72 → 93              → 5.20 s
#   03. 93 → 56              → 4.28 s
#   04. 56 → 48              → 5.50 s
#   05. 48 → 40              → 5.92 s
#   06. 40 → 3               → 6.01 s
#   07. 3 → 30               → 3.56 s
#   08. 30 → 65              → 4.71 s
#   09. 65 → O               → 4.51 s
# Tổng thời gian chu kỳ 25: 60.94 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 26: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 19   | Tọa độ: (26.60, 28.70, 22.39)
#   02. Node ID: 71   | Tọa độ: (15.09, 23.93, 70.10)
#   03. Node ID: 95   | Tọa độ: (19.96, 81.90, 50.80)
#   04. Node ID: 50   | Tọa độ: (27.19, 75.45, 16.50)
#   05. Node ID: 76   | Tọa độ: (86.15, 72.41, 25.89)
#   06. Node ID: 6    | Tọa độ: (69.75, 71.21, 82.77)
#   07. Node ID: 7    | Tọa độ: (66.49, 25.48, 77.55)
#   08. Node ID: 94   | Tọa độ: (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 19               → 4.51 s
#   02. 19 → 71              → 4.93 s
#   03. 71 → 95              → 6.13 s
#   04. 95 → 50              → 3.56 s
#   05. 50 → 76              → 5.98 s
#   06. 76 → 6               → 5.92 s
#   07. 6 → 7                → 4.61 s
#   08. 7 → 94               → 4.28 s
#   09. 94 → O               → 8.35 s
# Tổng thời gian chu kỳ 26: 61.21 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 27: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 8    | Tọa độ: (27.19, 75.45, 16.50)
#   02. Node ID: 23   | Tọa độ: (19.96, 81.90, 50.80)
#   03. Node ID: 54   | Tọa độ: (69.75, 71.21, 82.77)
#   04. Node ID: 88   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 15   | Tọa độ: (72.84, 19.97, 35.58)
#   06. Node ID: 14   | Tọa độ: (66.49, 25.48, 77.55)
#   07. Node ID: 18   | Tọa độ: (15.09, 23.93, 70.10)
#   08. Node ID: 66   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 8                → 8.19 s
#   02. 8 → 23               → 3.56 s
#   03. 23 → 54              → 6.01 s
#   04. 54 → 88              → 5.92 s
#   05. 88 → 15              → 5.50 s
#   06. 15 → 14              → 4.28 s
#   07. 14 → 18              → 5.20 s
#   08. 18 → 66              → 4.93 s
#   09. 66 → O               → 4.51 s
# Tổng thời gian chu kỳ 27: 60.14 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 28: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 25   | Tọa độ: (26.60, 28.70, 22.39)
#   02. Node ID: 5    | Tọa độ: (15.09, 23.93, 70.10)
#   03. Node ID: 60   | Tọa độ: (19.96, 81.90, 50.80)
#   04. Node ID: 97   | Tọa độ: (27.19, 75.45, 16.50)
#   05. Node ID: 48   | Tọa độ: (86.15, 72.41, 25.89)
#   06. Node ID: 12   | Tọa độ: (69.75, 71.21, 82.77)
#   07. Node ID: 79   | Tọa độ: (66.49, 25.48, 77.55)
#   08. Node ID: 89   | Tọa độ: (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 25               → 4.51 s
#   02. 25 → 5               → 4.93 s
#   03. 5 → 60               → 6.13 s
#   04. 60 → 97              → 3.56 s
#   05. 97 → 48              → 5.98 s
#   06. 48 → 12              → 5.92 s
#   07. 12 → 79              → 4.61 s
#   08. 79 → 89              → 4.28 s
#   09. 89 → O               → 8.35 s
# Tổng thời gian chu kỳ 28: 59.01 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 29: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 68   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 32   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 13   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 90   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 39   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 61   | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 50   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 65   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 68               → 7.56 s
#   02. 68 → 32              → 5.20 s
#   03. 32 → 13              → 4.28 s
#   04. 13 → 90              → 5.50 s
#   05. 90 → 39              → 5.92 s
#   06. 39 → 61              → 6.01 s
#   07. 61 → 50              → 3.56 s
#   08. 50 → 65              → 4.71 s
#   09. 65 → O               → 4.51 s
# Tổng thời gian chu kỳ 29: 60.06 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 30: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 8    | Tọa độ: (27.19, 75.45, 16.50)
#   02. Node ID: 81   | Tọa độ: (19.96, 81.90, 50.80)
#   03. Node ID: 0    | Tọa độ: (69.75, 71.21, 82.77)
#   04. Node ID: 52   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 28   | Tọa độ: (72.84, 19.97, 35.58)
#   06. Node ID: 22   | Tọa độ: (66.49, 25.48, 77.55)
#   07. Node ID: 16   | Tọa độ: (15.09, 23.93, 70.10)
#   08. Node ID: 78   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 8                → 8.19 s
#   02. 8 → 81               → 3.56 s
#   03. 81 → 0               → 6.01 s
#   04. 0 → 52               → 5.92 s
#   05. 52 → 28              → 5.50 s
#   06. 28 → 22              → 4.28 s
#   07. 22 → 16              → 5.20 s
#   08. 16 → 78              → 4.93 s
#   09. 78 → O               → 4.51 s
# Tổng thời gian chu kỳ 30: 60.79 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 31: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 77   | Tọa độ: (27.19, 75.45, 16.50)
#   02. Node ID: 53   | Tọa độ: (19.96, 81.90, 50.80)
#   03. Node ID: 45   | Tọa độ: (69.75, 71.21, 82.77)
#   04. Node ID: 88   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 80   | Tọa độ: (72.84, 19.97, 35.58)
#   06. Node ID: 38   | Tọa độ: (66.49, 25.48, 77.55)
#   07. Node ID: 72   | Tọa độ: (15.09, 23.93, 70.10)
#   08. Node ID: 98   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 77               → 8.19 s
#   02. 77 → 53              → 3.56 s
#   03. 53 → 45              → 6.01 s
#   04. 45 → 88              → 5.92 s
#   05. 88 → 80              → 5.50 s
#   06. 80 → 38              → 4.28 s
#   07. 38 → 72              → 5.20 s
#   08. 72 → 98              → 4.93 s
#   09. 98 → O               → 4.51 s
# Tổng thời gian chu kỳ 31: 59.38 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 32: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 71   | Tọa độ: (15.09, 23.93, 70.10)
#   02. Node ID: 83   | Tọa độ: (66.49, 25.48, 77.55)
#   03. Node ID: 55   | Tọa độ: (72.84, 19.97, 35.58)
#   04. Node ID: 90   | Tọa độ: (86.15, 72.41, 25.89)
#   05. Node ID: 40   | Tọa độ: (69.75, 71.21, 82.77)
#   06. Node ID: 3    | Tọa độ: (19.96, 81.90, 50.80)
#   07. Node ID: 97   | Tọa độ: (27.19, 75.45, 16.50)
#   08. Node ID: 21   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 71               → 7.56 s
#   02. 71 → 83              → 5.20 s
#   03. 83 → 55              → 4.28 s
#   04. 55 → 90              → 5.50 s
#   05. 90 → 40              → 5.92 s
#   06. 40 → 3               → 6.01 s
#   07. 3 → 97               → 3.56 s
#   08. 97 → 21              → 4.71 s
#   09. 21 → O               → 4.51 s
# Tổng thời gian chu kỳ 32: 59.68 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 33: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 66   | Tọa độ: (26.60, 28.70, 22.39)
#   02. Node ID: 5    | Tọa độ: (15.09, 23.93, 70.10)
#   03. Node ID: 60   | Tọa độ: (19.96, 81.90, 50.80)
#   04. Node ID: 17   | Tọa độ: (27.19, 75.45, 16.50)
#   05. Node ID: 48   | Tọa độ: (86.15, 72.41, 25.89)
#   06. Node ID: 49   | Tọa độ: (69.75, 71.21, 82.77)
#   07. Node ID: 11   | Tọa độ: (66.49, 25.48, 77.55)
#   08. Node ID: 67   | Tọa độ: (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 66               → 4.51 s
#   02. 66 → 5               → 4.93 s
#   03. 5 → 60               → 6.13 s
#   04. 60 → 17              → 3.56 s
#   05. 17 → 48              → 5.98 s
#   06. 48 → 49              → 5.92 s
#   07. 49 → 11              → 4.61 s
#   08. 11 → 67              → 4.28 s
#   09. 67 → O               → 8.35 s
# Tổng thời gian chu kỳ 33: 61.78 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 34: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 25   | Tọa độ: (26.60, 28.70, 22.39)
#   02. Node ID: 16   | Tọa độ: (15.09, 23.93, 70.10)
#   03. Node ID: 43   | Tọa độ: (19.96, 81.90, 50.80)
#   04. Node ID: 33   | Tọa độ: (27.19, 75.45, 16.50)
#   05. Node ID: 59   | Tọa độ: (86.15, 72.41, 25.89)
#   06. Node ID: 62   | Tọa độ: (69.75, 71.21, 82.77)
#   07. Node ID: 41   | Tọa độ: (66.49, 25.48, 77.55)
#   08. Node ID: 15   | Tọa độ: (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 25               → 4.51 s
#   02. 25 → 16              → 4.93 s
#   03. 16 → 43              → 6.13 s
#   04. 43 → 33              → 3.56 s
#   05. 33 → 59              → 5.98 s
#   06. 59 → 62              → 5.92 s
#   07. 62 → 41              → 4.61 s
#   08. 41 → 15              → 4.28 s
#   09. 15 → O               → 8.35 s
# Tổng thời gian chu kỳ 34: 58.52 s
# Sau cập nhật năng lượng: 99 nodes sống, 1 nodes chết
#
# Chu kỳ 35: 99/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 77   | Tọa độ: (27.19, 75.45, 16.50)
#   02. Node ID: 23   | Tọa độ: (19.96, 81.90, 50.80)
#   03. Node ID: 6    | Tọa độ: (69.75, 71.21, 82.77)
#   04. Node ID: 9    | Tọa độ: (79.98, 45.74, 29.95)
#   05. Node ID: 28   | Tọa độ: (65.94, 25.54, 76.14)
#   06. Node ID: 87   | Tọa độ: (15.09, 23.93, 70.10)
#   07. Node ID: 57   | Tọa độ: (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 77               → 8.19 s
#   02. 77 → 23              → 3.56 s
#   03. 23 → 6               → 6.01 s
#   04. 6 → 9                → 5.95 s
#   05. 9 → 28               → 5.23 s
#   06. 28 → 87              → 5.12 s
#   07. 87 → 57              → 4.93 s
#   08. 57 → O               → 4.51 s
# Tổng thời gian chu kỳ 35: 51.20 s
# Sau cập nhật năng lượng: 98 nodes sống, 2 nodes chết
#
# Chu kỳ 36: 98/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 98   | Tọa độ: (26.60, 28.70, 22.39)
#   02. Node ID: 96   | Tọa độ: (27.19, 75.45, 16.50)
#   03. Node ID: 95   | Tọa độ: (19.96, 81.90, 50.80)
#   04. Node ID: 24   | Tọa độ: (70.32, 69.81, 82.51)
#   05. Node ID: 52   | Tọa độ: (86.32, 72.68, 25.47)
#   06. Node ID: 89   | Tọa độ: (72.25, 19.75, 35.67)
#   07. Node ID: 79   | Tọa độ: (65.65, 24.19, 77.51)
#   08. Node ID: 72   | Tọa độ: (15.09, 23.93, 70.10)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 98               → 4.51 s
#   02. 98 → 96              → 4.71 s
#   03. 96 → 95              → 3.56 s
#   04. 95 → 24              → 6.07 s
#   05. 24 → 52              → 5.93 s
#   06. 52 → 89              → 5.57 s
#   07. 89 → 79              → 4.26 s
#   08. 79 → 72              → 5.11 s
#   09. 72 → O               → 7.56 s
# Tổng thời gian chu kỳ 36: 60.67 s
# Sau cập nhật năng lượng: 98 nodes sống, 2 nodes chết
#
# Chu kỳ 37: 98/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 82   | Tọa độ: (26.60, 28.70, 22.39)
#   02. Node ID: 71   | Tọa độ: (15.09, 23.93, 70.10)
#   03. Node ID: 36   | Tọa độ: (19.96, 81.90, 50.80)
#   04. Node ID: 17   | Tọa độ: (27.19, 75.45, 16.50)
#   05. Node ID: 88   | Tọa độ: (86.32, 72.68, 25.47)
#   06. Node ID: 35   | Tọa độ: (70.32, 69.81, 82.51)
#   07. Node ID: 27   | Tọa độ: (65.65, 24.19, 77.51)
#   08. Node ID: 94   | Tọa độ: (72.25, 19.75, 35.67)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 82               → 4.51 s
#   02. 82 → 71              → 4.93 s
#   03. 71 → 36              → 6.13 s
#   04. 36 → 17              → 3.56 s
#   05. 17 → 88              → 5.99 s
#   06. 88 → 35              → 5.93 s
#   07. 35 → 27              → 4.61 s
#   08. 27 → 94              → 4.26 s
#   09. 94 → O               → 8.30 s
# Tổng thời gian chu kỳ 37: 61.43 s
# Sau cập nhật năng lượng: 97 nodes sống, 3 nodes chết
#
# Chu kỳ 38: 97/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 57   | Tọa độ: (26.60, 28.70, 22.39)
#   02. Node ID: 85   | Tọa độ: (15.09, 23.93, 70.10)
#   03. Node ID: 32   | Tọa độ: (65.65, 24.19, 77.51)
#   04. Node ID: 86   | Tọa độ: (72.25, 19.75, 35.67)
#   05. Node ID: 59   | Tọa độ: (86.32, 72.68, 25.47)
#   06. Node ID: 69   | Tọa độ: (70.32, 69.81, 82.51)
#   07. Node ID: 43   | Tọa độ: (23.20, 78.78, 35.27)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 57               → 4.51 s
#   02. 57 → 85              → 4.93 s
#   03. 85 → 32              → 5.11 s
#   04. 32 → 86              → 4.26 s
#   05. 86 → 59              → 5.57 s
#   06. 59 → 69              → 5.93 s
#   07. 69 → 43              → 6.73 s
#   08. 43 → O               → 8.94 s
# Tổng thời gian chu kỳ 38: 56.12 s
# Sau cập nhật năng lượng: 93 nodes sống, 7 nodes chết
#
# Chu kỳ 39: 93/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 66   | Tọa độ: (26.14, 27.59, 22.53)
#   02. Node ID: 5    | Tọa độ: (15.09, 23.93, 70.10)
#   03. Node ID: 11   | Tọa độ: (65.65, 24.19, 77.51)
#   04. Node ID: 67   | Tọa độ: (72.25, 19.75, 35.67)
#   05. Node ID: 34   | Tọa độ: (85.27, 72.63, 25.48)
#   06. Node ID: 0    | Tọa độ: (69.95, 69.52, 82.05)
#   07. Node ID: 43   | Tọa độ: (23.03, 78.85, 34.72)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 66               → 4.42 s
#   02. 66 → 5               → 4.90 s
#   03. 5 → 11               → 5.11 s
#   04. 11 → 67              → 4.26 s
#   05. 67 → 34              → 5.54 s
#   06. 34 → 0               → 5.87 s
#   07. 0 → 43               → 6.73 s
#   08. 43 → O               → 8.92 s
# Tổng thời gian chu kỳ 39: 59.18 s
# Sau cập nhật năng lượng: 93 nodes sống, 7 nodes chết
#
# Chu kỳ 40: 93/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 82   | Tọa độ: (26.14, 27.59, 22.53)
#   02. Node ID: 87   | Tọa độ: (15.09, 23.93, 70.10)
#   03. Node ID: 1    | Tọa độ: (65.65, 24.19, 77.51)
#   04. Node ID: 80   | Tọa độ: (72.25, 19.75, 35.67)
#   05. Node ID: 90   | Tọa độ: (85.27, 72.63, 25.48)
#   06. Node ID: 92   | Tọa độ: (69.95, 69.52, 82.05)
#   07. Node ID: 33   | Tọa độ: (23.03, 78.85, 34.72)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 82               → 4.42 s
#   02. 82 → 87              → 4.90 s
#   03. 87 → 1               → 5.11 s
#   04. 1 → 80               → 4.26 s
#   05. 80 → 90              → 5.54 s
#   06. 90 → 92              → 5.87 s
#   07. 92 → 33              → 6.73 s
#   08. 33 → O               → 8.92 s
# Tổng thời gian chu kỳ 40: 59.16 s
# Sau cập nhật năng lượng: 91 nodes sống, 9 nodes chết
#
# Chu kỳ 41: 91/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 98   | Tọa độ: (26.14, 27.59, 22.53)
#   02. Node ID: 55   | Tọa độ: (72.25, 19.75, 35.67)
#   03. Node ID: 91   | Tọa độ: (65.65, 24.19, 77.51)
#   04. Node ID: 49   | Tọa độ: (69.95, 69.52, 82.05)
#   05. Node ID: 34   | Tọa độ: (85.27, 72.63, 25.48)
#   06. Node ID: 96   | Tọa độ: (22.54, 79.53, 35.92)
#   07. Node ID: 85   | Tọa độ: (14.56, 24.64, 70.53)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 98               → 4.42 s
#   02. 98 → 55              → 4.86 s
#   03. 55 → 91              → 4.26 s
#   04. 91 → 49              → 4.58 s
#   05. 49 → 34              → 5.87 s
#   06. 34 → 96              → 6.40 s
#   07. 96 → 85              → 6.54 s
#   08. 85 → O               → 7.61 s
# Tổng thời gian chu kỳ 41: 58.28 s
# Sau cập nhật năng lượng: 88 nodes sống, 12 nodes chết
#
# Chu kỳ 42: 88/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 16   | Tọa độ: (21.25, 22.84, 44.73)
#   02. Node ID: 64   | Tọa độ: (21.57, 76.95, 41.00)
#   03. Node ID: 92   | Tọa độ: (71.86, 80.17, 48.09)
#   04. Node ID: 40   | Tọa độ: (69.73, 56.99, 87.52)
#   05. Node ID: 89   | Tọa độ: (67.19, 13.02, 58.96)
#   06. Node ID: 67   | Tọa độ: (80.15, 44.76, 23.59)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 16               → 5.45 s
#   02. 16 → 64              → 5.42 s
#   03. 64 → 92              → 5.09 s
#   04. 92 → 40              → 4.58 s
#   05. 40 → 89              → 5.25 s
#   06. 89 → 67              → 4.93 s
#   07. 67 → O               → 9.48 s
# Tổng thời gian chu kỳ 42: 55.78 s
# Sau cập nhật năng lượng: 88 nodes sống, 12 nodes chết
#
# Chu kỳ 43: 88/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 60   | Tọa độ: (21.57, 76.95, 41.00)
#   02. Node ID: 69   | Tọa độ: (69.73, 56.99, 87.52)
#   03. Node ID: 35   | Tọa độ: (71.86, 80.17, 48.09)
#   04. Node ID: 86   | Tọa độ: (80.15, 44.76, 23.59)
#   05. Node ID: 11   | Tọa độ: (67.19, 13.02, 58.96)
#   06. Node ID: 72   | Tọa độ: (21.25, 22.84, 44.73)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 60               → 8.98 s
#   02. 60 → 69              → 6.99 s
#   03. 69 → 35              → 4.58 s
#   04. 35 → 86              → 4.39 s
#   05. 86 → 11              → 4.93 s
#   06. 11 → 72              → 4.91 s
#   07. 72 → O               → 5.45 s
# Tổng thời gian chu kỳ 43: 56.58 s
# Sau cập nhật năng lượng: 79 nodes sống, 21 nodes chết
#
# Chu kỳ 44: 79/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 33   | Tọa độ: (15.37, 59.62, 38.00)
#   02. Node ID: 4    | Tọa độ: (66.22, 57.84, 18.08)
#   03. Node ID: 99   | Tọa độ: (77.74, 82.51, 86.75)
#   04. Node ID: 47   | Tọa độ: (63.45, 47.94, 75.57)
#   05. Node ID: 27   | Tọa độ: (53.93, 13.75, 60.82)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 33               → 7.24 s
#   02. 33 → 4               → 5.46 s
#   03. 4 → 99               → 7.39 s
#   04. 99 → 47              → 3.90 s
#   05. 47 → 27              → 3.84 s
#   06. 27 → O               → 8.24 s
# Tổng thời gian chu kỳ 44: 51.47 s
# Sau cập nhật năng lượng: 68 nodes sống, 32 nodes chết
#
# Chu kỳ 45: 68/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 82   | Tọa độ: (45.25, 29.46, 15.51)
#   02. Node ID: 4    | Tọa độ: (40.62, 78.41, 36.62)
#   03. Node ID: 99   | Tọa độ: (77.74, 82.51, 86.75)
#   04. Node ID: 45   | Tọa độ: (63.45, 47.94, 75.57)
#   05. Node ID: 27   | Tọa độ: (53.17, 8.45, 64.54)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 82               → 5.62 s
#   02. 82 → 4               → 5.35 s
#   03. 4 → 99               → 6.25 s
#   04. 99 → 45              → 3.90 s
#   05. 45 → 27              → 4.23 s
#   06. 27 → O               → 8.41 s
# Tổng thời gian chu kỳ 45: 47.97 s
# Sau cập nhật năng lượng: 68 nodes sống, 32 nodes chết
#
# Chu kỳ 46: 68/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 96   | Tọa độ: (40.62, 78.41, 36.62)
#   02. Node ID: 2    | Tọa độ: (77.74, 82.51, 86.75)
#   03. Node ID: 47   | Tọa độ: (63.45, 47.94, 75.57)
#   04. Node ID: 70   | Tọa độ: (53.17, 8.45, 64.54)
#   05. Node ID: 15   | Tọa độ: (45.25, 29.46, 15.51)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 96               → 9.56 s
#   02. 96 → 2               → 6.25 s
#   03. 2 → 47               → 3.90 s
#   04. 47 → 70              → 4.23 s
#   05. 70 → 15              → 5.39 s
#   06. 15 → O               → 5.62 s
# Tổng thời gian chu kỳ 46: 51.00 s
# Sau cập nhật năng lượng: 29 nodes sống, 71 nodes chết
#
# Chu kỳ 47: 29/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 29   | Tọa độ: (56.99, 55.21, 77.88)
#   02. Node ID: 9    | Tọa độ: (62.79, 63.13, 17.34)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 29               → 11.12 s
#   02. 29 → 9               → 6.13 s
#   03. 9 → O                → 9.07 s
# Tổng thời gian chu kỳ 47: 48.86 s
# Sau cập nhật năng lượng: 6 nodes sống, 94 nodes chết
#
# Mạng sập sau cập nhật: 94/100 nodes chết
#
# Tổng số chu kỳ hoàn thành: 47
# Tổng thời gian di chuyển của AUV: 2745.57 s
