# %%
# simulate_auv.py
import json
import numpy as np
from clustering import cluster_split, choose_cluster_head
from select_path_greedy import compute_travel_time, path_selection

def simulate_auv_cycle(data, r_sen=100, R=20, E_tx=5, E_rx=2, v_AUV=10, death_threshold=0.9):
    
    positions = np.array([[d["x"], d["y"], d["z"]] for d in data])
    energies = {d["id"]: d["energy_node"] for d in data}
    node_ids = [d["id"] for d in data]
    total_nodes = len(node_ids)
    cycle = 0
    total_travel_time = 0.0

    while True:
        alive_ids = [nid for nid, e in energies.items() if e > 0]
        alive_count = len(alive_ids)
        dead_count = total_nodes - alive_count
        dead_ratio = dead_count / total_nodes

        # điều kiện dừng
        if dead_ratio >= death_threshold:
            print(f"\nMạng sập: {dead_count}/{total_nodes} nodes chết ({dead_ratio*100:.1f}%)")
            break

        cycle += 1
        print(f"\nChu kỳ {cycle}: {alive_count}/{total_nodes} nodes hoạt động")

        # lấy pos của nodes còn sống
        alive_positions = np.array([positions[nid] for nid in alive_ids])

        # phân cụm các node còn sống (trả về danh sách cụm)
        clusters_raw = cluster_split(alive_positions, alive_ids, r_sen=r_sen, R=R)
        cluster_heads = []
        positions_dict = {}

        for c in clusters_raw:
            ch = choose_cluster_head(c, energies)
            cluster_heads.append(ch)
            # dùng tâm cụm để tính khoảng cách 
            positions_dict[ch] = np.mean(c["nodes"], axis=0)

        # nếu không có cluster head (ví dụ quá ít node), thoát
        if len(cluster_heads) == 0:
            print("Không còn cluster head nào — dừng mô phỏng.")
            break

        # tính ma trận thời gian di chuyển và tìm đường
        travel_time = compute_travel_time(cluster_heads, positions_dict, v_AUV)
        best_path, best_time = path_selection(cluster_heads, travel_time, positions, v_AUV)

        # tạo danh sách chi tiết các segment
        O = np.array([0, 0, 0])
        segment_times = []

        # Từ O đến nút đầu tiên
        first_ch = cluster_heads[best_path[0]]
        start_dist = np.linalg.norm(positions_dict[first_ch] - O)
        start_time = start_dist / v_AUV
        segment_times.append((f"O → {first_ch}", start_time))

        # giữa các CH
        for i in range(1, len(best_path)):
            from_idx = cluster_heads[best_path[i-1]]
            to_idx = cluster_heads[best_path[i]]
            seg_time = travel_time[best_path[i-1]][best_path[i]]
            segment_times.append((f"{from_idx} → {to_idx}", seg_time))

        # nút cuối về O
        last_ch = cluster_heads[best_path[-1]]
        end_dist = np.linalg.norm(positions_dict[last_ch] - O)
        end_time = end_dist / v_AUV
        segment_times.append((f"{last_ch} → O", end_time))

        # tổng thời gian 
        cycle_time = best_time + start_time + end_time
        total_travel_time += cycle_time
        

    
        print("\nĐường đi tối ưu chi tiết (theo thứ tự thăm của AUV):")
        path_ids = [cluster_heads[i] for i in best_path]
        for idx, node_id in enumerate(path_ids, start=1):
            pos = positions_dict[node_id]
            print(f"  {idx:02d}. Node ID: {node_id:<3}  | Tọa độ: ({pos[0]:.2f}, {pos[1]:.2f}, {pos[2]:.2f})")
        print("về O(0, 0, 0)")
        print("\nThời gian từng chặng trong chu kỳ:")
        for idx, (seg_desc, t) in enumerate(segment_times, start=1):
            print(f"  {idx:02d}. {seg_desc:<20} → {t:.2f} s")
        print(f"Tổng thời gian chu kỳ {cycle}: {cycle_time:.2f} s")

        # cập nhật năng lượng cho các node
        for c in clusters_raw:
            ch = choose_cluster_head(c, energies)
            energies[ch] -= E_tx
            if energies[ch] < 0:
                energies[ch] = 0
            for nid in c["node_ids"]:
                if nid != ch:
                    energies[nid] -= E_rx
                    if energies[nid] < 0:
                        energies[nid] = 0

        # in trạng thái tóm tắt
        alive_count_after = len([e for e in energies.values() if e > 0])
        dead_count_after = total_nodes - alive_count_after
        print(f"Sau cập nhật năng lượng: {alive_count_after} nodes sống, {dead_count_after} nodes chết")

        # kiểm tra điều kiện dừng
        if (total_nodes - alive_count_after) / total_nodes >= death_threshold:
            print(f"\nMạng sập sau cập nhật: {(total_nodes - alive_count_after)}/{total_nodes} nodes chết")
            break

    print(f"\nTổng số chu kỳ hoàn thành: {cycle}")
    print(f"Tổng thời gian di chuyển của AUV: {total_travel_time:.2f} s")
    return cycle, total_travel_time


# chạy mô phỏng 
if __name__ == "__main__":
    with open("input_data/nodes_100.json", "r") as f:
        data = json.load(f)
    simulate_auv_cycle(data)
# Out:
# Chu kỳ 1: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 51   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 51              → 5.20 s
#   03. 51 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 10              → 6.01 s
#   07. 10 → 74              → 3.56 s
#   08. 74 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 1: 59.77 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 2: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 20   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 51   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 20               → 7.56 s
#   02. 20 → 51              → 5.20 s
#   03. 51 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 10              → 6.01 s
#   07. 10 → 74              → 3.56 s
#   08. 74 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 2: 59.57 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 3: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 44   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 46   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 73   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 36   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 19   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 44               → 7.56 s
#   02. 44 → 46              → 5.20 s
#   03. 46 → 58              → 4.28 s
#   04. 58 → 76              → 5.50 s
#   05. 76 → 73              → 5.92 s
#   06. 73 → 36              → 6.01 s
#   07. 36 → 30              → 3.56 s
#   08. 30 → 19              → 4.71 s
#   09. 19 → O               → 4.51 s
# Tổng thời gian chu kỳ 3: 59.67 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 4: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 42   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 93   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 56   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 75   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 12   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 61   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 26   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 42               → 7.56 s
#   02. 42 → 93              → 5.20 s
#   03. 93 → 56              → 4.28 s
#   04. 56 → 75              → 5.50 s
#   05. 75 → 12              → 5.92 s
#   06. 12 → 61              → 6.01 s
#   07. 61 → 74              → 3.56 s
#   08. 74 → 26              → 4.71 s
#   09. 26 → O               → 4.51 s
# Tổng thời gian chu kỳ 4: 59.01 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 5: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 14   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 58   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 84   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 14              → 5.20 s
#   03. 14 → 58              → 4.28 s
#   04. 58 → 37              → 5.50 s
#   05. 37 → 84              → 5.92 s
#   06. 84 → 10              → 6.01 s
#   07. 10 → 30              → 3.56 s
#   08. 30 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 5: 59.77 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 6: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 20   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 22   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 13   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 73   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 81   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 97   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 78   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 20               → 7.56 s
#   02. 20 → 22              → 5.20 s
#   03. 22 → 13              → 4.28 s
#   04. 13 → 76              → 5.50 s
#   05. 76 → 73              → 5.92 s
#   06. 73 → 81              → 6.01 s
#   07. 81 → 97              → 3.56 s
#   08. 97 → 78              → 4.71 s
#   09. 78 → O               → 4.51 s
# Tổng thời gian chu kỳ 6: 60.12 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 7: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 44   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 38   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 31   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 75   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 54   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 95   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 50   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 21   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 44               → 7.56 s
#   02. 44 → 38              → 5.20 s
#   03. 38 → 31              → 4.28 s
#   04. 31 → 75              → 5.50 s
#   05. 75 → 54              → 5.92 s
#   06. 54 → 95              → 6.01 s
#   07. 95 → 50              → 3.56 s
#   08. 50 → 21              → 4.71 s
#   09. 21 → O               → 4.51 s
# Tổng thời gian chu kỳ 7: 58.22 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 8: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 8    | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 36   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 12   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 37   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 56   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 41   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 42   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 19   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 8                → 8.19 s
#   02. 8 → 36               → 3.56 s
#   03. 36 → 12              → 6.01 s
#   04. 12 → 37              → 5.92 s
#   05. 37 → 56              → 5.50 s
#   06. 56 → 41              → 4.28 s
#   07. 41 → 42              → 5.20 s
#   08. 42 → 19              → 4.93 s
#   09. 19 → O               → 4.51 s
# Tổng thời gian chu kỳ 8: 60.60 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 9: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 68   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 1    | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 94   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 62   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 53   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 74   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 65   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 68               → 7.56 s
#   02. 68 → 1               → 5.20 s
#   03. 1 → 94               → 4.28 s
#   04. 94 → 76              → 5.50 s
#   05. 76 → 62              → 5.92 s
#   06. 62 → 53              → 6.01 s
#   07. 53 → 74              → 3.56 s
#   08. 74 → 65              → 4.71 s
#   09. 65 → O               → 4.51 s
# Tổng thời gian chu kỳ 9: 60.06 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 10: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 7    | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 13   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 48   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 6    | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 3    | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 97   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 26   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 7               → 5.20 s
#   03. 7 → 13               → 4.28 s
#   04. 13 → 48              → 5.50 s
#   05. 48 → 6               → 5.92 s
#   06. 6 → 3                → 6.01 s
#   07. 3 → 97               → 3.56 s
#   08. 97 → 26              → 4.71 s
#   09. 26 → O               → 4.51 s
# Tổng thời gian chu kỳ 10: 58.80 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 11: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 16   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 32   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 80   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 75   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 39   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 23   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 25   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 16               → 7.56 s
#   02. 16 → 32              → 5.20 s
#   03. 32 → 80              → 4.28 s
#   04. 80 → 75              → 5.50 s
#   05. 75 → 39              → 5.92 s
#   06. 39 → 23              → 6.01 s
#   07. 23 → 30              → 3.56 s
#   08. 30 → 25              → 4.71 s
#   09. 25 → O               → 4.51 s
# Tổng thời gian chu kỳ 11: 57.81 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 12: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 72   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 83   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 55   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 88   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 45   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 61   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 50   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 78   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 72               → 7.56 s
#   02. 72 → 83              → 5.20 s
#   03. 83 → 55              → 4.28 s
#   04. 55 → 88              → 5.50 s
#   05. 88 → 45              → 5.92 s
#   06. 45 → 61              → 6.01 s
#   07. 61 → 50              → 3.56 s
#   08. 50 → 78              → 4.71 s
#   09. 78 → O               → 4.51 s
# Tổng thời gian chu kỳ 12: 61.00 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 13: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 8    | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 81   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 40   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 90   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 15   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 46   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 71   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 21   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 8                → 8.19 s
#   02. 8 → 81               → 3.56 s
#   03. 81 → 40              → 6.01 s
#   04. 40 → 90              → 5.92 s
#   05. 90 → 15              → 5.50 s
#   06. 15 → 46              → 4.28 s
#   07. 46 → 71              → 5.20 s
#   08. 71 → 21              → 4.93 s
#   09. 21 → O               → 4.51 s
# Tổng thời gian chu kỳ 13: 59.16 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 14: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 66   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
#   02. Node ID: 5    | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   03. Node ID: 60   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   04. Node ID: 97   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   05. Node ID: 48   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   06. Node ID: 0    | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   07. Node ID: 51   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   08. Node ID: 89   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 66               → 4.51 s
#   02. 66 → 5               → 4.93 s
#   03. 5 → 60               → 6.13 s
#   04. 60 → 97              → 3.56 s
#   05. 97 → 48              → 5.98 s
#   06. 48 → 0               → 5.92 s
#   07. 0 → 51               → 4.61 s
#   08. 51 → 89              → 4.28 s
#   09. 89 → O               → 8.35 s
# Tổng thời gian chu kỳ 14: 61.29 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 15: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 77   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 95   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 54   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 76   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 31   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 79   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 20   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 98   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 77               → 8.19 s
#   02. 77 → 95              → 3.56 s
#   03. 95 → 54              → 6.01 s
#   04. 54 → 76              → 5.92 s
#   05. 76 → 31              → 5.50 s
#   06. 31 → 79              → 4.28 s
#   07. 79 → 20              → 5.20 s
#   08. 20 → 98              → 4.93 s
#   09. 98 → O               → 4.51 s
# Tổng thời gian chu kỳ 15: 59.38 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 16: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 68   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 93   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 28   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 52   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 49   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 10   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 63   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 68               → 7.56 s
#   02. 68 → 93              → 5.20 s
#   03. 93 → 28              → 4.28 s
#   04. 28 → 52              → 5.50 s
#   05. 52 → 49              → 5.92 s
#   06. 49 → 10              → 6.01 s
#   07. 10 → 30              → 3.56 s
#   08. 30 → 63              → 4.71 s
#   09. 63 → O               → 4.51 s
# Tổng thời gian chu kỳ 16: 59.56 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 17: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 44   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 14   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 67   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 59   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 73   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 53   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 50   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 65   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 44               → 7.56 s
#   02. 44 → 14              → 5.20 s
#   03. 14 → 67              → 4.28 s
#   04. 67 → 59              → 5.50 s
#   05. 59 → 73              → 5.92 s
#   06. 73 → 53              → 6.01 s
#   07. 53 → 50              → 3.56 s
#   08. 50 → 65              → 4.71 s
#   09. 65 → O               → 4.51 s
# Tổng thời gian chu kỳ 17: 59.80 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 18: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 42   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 22   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 94   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 37   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 62   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 43   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 17   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 19   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 42               → 7.56 s
#   02. 42 → 22              → 5.20 s
#   03. 22 → 94              → 4.28 s
#   04. 94 → 37              → 5.50 s
#   05. 37 → 62              → 5.92 s
#   06. 62 → 43              → 6.01 s
#   07. 43 → 17              → 3.56 s
#   08. 17 → 19              → 4.71 s
#   09. 19 → O               → 4.51 s
# Tổng thời gian chu kỳ 18: 60.35 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 19: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 16   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 11   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 56   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 88   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 6    | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 3    | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 33   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 57   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 16               → 7.56 s
#   02. 16 → 11              → 5.20 s
#   03. 11 → 56              → 4.28 s
#   04. 56 → 88              → 5.50 s
#   05. 88 → 6               → 5.92 s
#   06. 6 → 3                → 6.01 s
#   07. 3 → 33               → 3.56 s
#   08. 33 → 57              → 4.71 s
#   09. 57 → O               → 4.51 s
# Tổng thời gian chu kỳ 19: 56.79 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 20: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 74   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 23   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 12   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 90   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 86   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 38   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 87   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 25   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 74               → 8.19 s
#   02. 74 → 23              → 3.56 s
#   03. 23 → 12              → 6.01 s
#   04. 12 → 90              → 5.92 s
#   05. 90 → 86              → 5.50 s
#   06. 86 → 38              → 4.28 s
#   07. 38 → 87              → 5.20 s
#   08. 87 → 25              → 4.93 s
#   09. 25 → O               → 4.51 s
# Tổng thời gian chu kỳ 20: 59.83 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 21: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 72   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 41   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 80   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 9    | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 35   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 36   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 96   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 26   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 72               → 7.56 s
#   02. 72 → 41              → 5.20 s
#   03. 41 → 80              → 4.28 s
#   04. 80 → 9               → 5.50 s
#   05. 9 → 35               → 5.92 s
#   06. 35 → 36              → 6.01 s
#   07. 36 → 96              → 3.56 s
#   08. 96 → 26              → 4.71 s
#   09. 26 → O               → 4.51 s
# Tổng thời gian chu kỳ 21: 59.47 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 22: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 8    | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 64   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 69   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 34   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 55   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 1    | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 71   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 82   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 8                → 8.19 s
#   02. 8 → 64               → 3.56 s
#   03. 64 → 69              → 6.01 s
#   04. 69 → 34              → 5.92 s
#   05. 34 → 55              → 5.50 s
#   06. 55 → 1               → 4.28 s
#   07. 1 → 71               → 5.20 s
#   08. 71 → 82              → 4.93 s
#   09. 82 → O               → 4.51 s
# Tổng thời gian chu kỳ 22: 60.88 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 23: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 66   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
#   02. Node ID: 85   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   03. Node ID: 60   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   04. Node ID: 4    | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   05. Node ID: 52   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   06. Node ID: 24   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   07. Node ID: 7    | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   08. Node ID: 15   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 66               → 4.51 s
#   02. 66 → 85              → 4.93 s
#   03. 85 → 60              → 6.13 s
#   04. 60 → 4               → 3.56 s
#   05. 4 → 52               → 5.98 s
#   06. 52 → 24              → 5.92 s
#   07. 24 → 7               → 4.61 s
#   08. 7 → 15               → 4.28 s
#   09. 15 → O               → 8.35 s
# Tổng thời gian chu kỳ 23: 60.80 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 24: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 77   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 61   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 39   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 48   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 89   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 27   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 5    | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 98   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 77               → 8.19 s
#   02. 77 → 61              → 3.56 s
#   03. 61 → 39              → 6.01 s
#   04. 39 → 48              → 5.92 s
#   05. 48 → 89              → 5.50 s
#   06. 89 → 27              → 4.28 s
#   07. 27 → 5               → 5.20 s
#   08. 5 → 98               → 4.93 s
#   09. 98 → O               → 4.51 s
# Tổng thời gian chu kỳ 24: 59.38 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 25: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 18   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 32   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 28   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 59   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 92   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 81   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 17   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 78   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 18               → 7.56 s
#   02. 18 → 32              → 5.20 s
#   03. 32 → 28              → 4.28 s
#   04. 28 → 59              → 5.50 s
#   05. 59 → 92              → 5.92 s
#   06. 92 → 81              → 6.01 s
#   07. 81 → 17              → 3.56 s
#   08. 17 → 78              → 4.71 s
#   09. 78 → O               → 4.51 s
# Tổng thời gian chu kỳ 25: 60.32 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 26: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 33   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 43   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 45   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 75   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 67   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 91   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 29   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 21   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 33               → 8.19 s
#   02. 33 → 43              → 3.56 s
#   03. 43 → 45              → 6.01 s
#   04. 45 → 75              → 5.92 s
#   05. 75 → 67              → 5.50 s
#   06. 67 → 91              → 4.28 s
#   07. 91 → 29              → 5.20 s
#   08. 29 → 21              → 4.93 s
#   09. 21 → O               → 4.51 s
# Tổng thời gian chu kỳ 26: 59.79 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 27: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 57   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
#   02. Node ID: 87   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   03. Node ID: 95   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   04. Node ID: 96   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   05. Node ID: 9    | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   06. Node ID: 40   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   07. Node ID: 70   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   08. Node ID: 13   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 57               → 4.51 s
#   02. 57 → 87              → 4.93 s
#   03. 87 → 95              → 6.13 s
#   04. 95 → 96              → 3.56 s
#   05. 96 → 9               → 5.98 s
#   06. 9 → 40               → 5.92 s
#   07. 40 → 70              → 4.61 s
#   08. 70 → 13              → 4.28 s
#   09. 13 → O               → 8.35 s
# Tổng thời gian chu kỳ 27: 59.22 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 28: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 68   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 83   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 31   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 34   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 99   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 53   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 97   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 65   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 68               → 7.56 s
#   02. 68 → 83              → 5.20 s
#   03. 83 → 31              → 4.28 s
#   04. 31 → 34              → 5.50 s
#   05. 34 → 99              → 5.92 s
#   06. 99 → 53              → 6.01 s
#   07. 53 → 97              → 3.56 s
#   08. 97 → 65              → 4.71 s
#   09. 65 → O               → 4.51 s
# Tổng thời gian chu kỳ 28: 60.06 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 29: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 85   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 47   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 86   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 88   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 2    | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 64   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 4    | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 82   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 85               → 7.56 s
#   02. 85 → 47              → 5.20 s
#   03. 47 → 86              → 4.28 s
#   04. 86 → 88              → 5.50 s
#   05. 88 → 2               → 5.92 s
#   06. 2 → 64               → 6.01 s
#   07. 64 → 4               → 3.56 s
#   08. 4 → 82               → 4.71 s
#   09. 82 → O               → 4.51 s
# Tổng thời gian chu kỳ 29: 61.45 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 30: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 77   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 3    | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 0    | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 90   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 94   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 79   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 16   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 25   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 77               → 8.19 s
#   02. 77 → 3               → 3.56 s
#   03. 3 → 0                → 6.01 s
#   04. 0 → 90               → 5.92 s
#   05. 90 → 94              → 5.50 s
#   06. 94 → 79              → 4.28 s
#   07. 79 → 16              → 5.20 s
#   08. 16 → 25              → 4.93 s
#   09. 25 → O               → 4.51 s
# Tổng thời gian chu kỳ 30: 56.80 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 31: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 72   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 11   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 80   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 52   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 49   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 23   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 50   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 66   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 72               → 7.56 s
#   02. 72 → 11              → 5.20 s
#   03. 11 → 80              → 4.28 s
#   04. 80 → 52              → 5.50 s
#   05. 52 → 49              → 5.92 s
#   06. 49 → 23              → 6.01 s
#   07. 23 → 50              → 3.56 s
#   08. 50 → 66              → 4.71 s
#   09. 66 → O               → 4.51 s
# Tổng thời gian chu kỳ 31: 60.35 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 32: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 71   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 27   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 55   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 59   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 35   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 60   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 17   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 98   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 71               → 7.56 s
#   02. 71 → 27              → 5.20 s
#   03. 27 → 55              → 4.28 s
#   04. 55 → 59              → 5.50 s
#   05. 59 → 35              → 5.92 s
#   06. 35 → 60              → 6.01 s
#   07. 60 → 17              → 3.56 s
#   08. 17 → 98              → 4.71 s
#   09. 98 → O               → 4.51 s
# Tổng thời gian chu kỳ 32: 60.95 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 33: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 57   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
#   02. Node ID: 29   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   03. Node ID: 43   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   04. Node ID: 33   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   05. Node ID: 9    | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   06. Node ID: 69   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   07. Node ID: 91   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   08. Node ID: 15   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 57               → 4.51 s
#   02. 57 → 29              → 4.93 s
#   03. 29 → 43              → 6.13 s
#   04. 43 → 33              → 3.56 s
#   05. 33 → 9               → 5.98 s
#   06. 9 → 69               → 5.92 s
#   07. 69 → 91              → 4.61 s
#   08. 91 → 15              → 4.28 s
#   09. 15 → O               → 8.35 s
# Tổng thời gian chu kỳ 33: 57.50 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 34: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 19   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
#   02. Node ID: 5    | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   03. Node ID: 36   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   04. Node ID: 96   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   05. Node ID: 34   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   06. Node ID: 24   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   07. Node ID: 70   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   08. Node ID: 89   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 19               → 4.51 s
#   02. 19 → 5               → 4.93 s
#   03. 5 → 36               → 6.13 s
#   04. 36 → 96              → 3.56 s
#   05. 96 → 34              → 5.98 s
#   06. 34 → 24              → 5.92 s
#   07. 24 → 70              → 4.61 s
#   08. 70 → 89              → 4.28 s
#   09. 89 → O               → 8.35 s
# Tổng thời gian chu kỳ 34: 61.76 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 35: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 82   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
#   02. Node ID: 87   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   03. Node ID: 64   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   04. Node ID: 4    | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   05. Node ID: 48   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   06. Node ID: 92   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   07. Node ID: 46   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   08. Node ID: 28   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 82               → 4.51 s
#   02. 82 → 87              → 4.93 s
#   03. 87 → 64              → 6.13 s
#   04. 64 → 4               → 3.56 s
#   05. 4 → 48               → 5.98 s
#   06. 48 → 92              → 5.92 s
#   07. 92 → 46              → 4.61 s
#   08. 46 → 28              → 4.28 s
#   09. 28 → O               → 8.35 s
# Tổng thời gian chu kỳ 35: 62.55 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 36: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 8    | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 61   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 99   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 88   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 67   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 47   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 85   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 26   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 8                → 8.19 s
#   02. 8 → 61               → 3.56 s
#   03. 61 → 99              → 6.01 s
#   04. 99 → 88              → 5.92 s
#   05. 88 → 67              → 5.50 s
#   06. 67 → 47              → 4.28 s
#   07. 47 → 85              → 5.20 s
#   08. 85 → 26              → 4.93 s
#   09. 26 → O               → 4.51 s
# Tổng thời gian chu kỳ 36: 59.26 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 37: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 77   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 81   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 2    | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 90   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 86   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 93   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 20   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 78   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 77               → 8.19 s
#   02. 77 → 81              → 3.56 s
#   03. 81 → 2               → 6.01 s
#   04. 2 → 90               → 5.92 s
#   05. 90 → 86              → 5.50 s
#   06. 86 → 93              → 4.28 s
#   07. 93 → 20              → 5.20 s
#   08. 20 → 78              → 4.93 s
#   09. 78 → O               → 4.51 s
# Tổng thời gian chu kỳ 37: 59.73 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 38: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 44   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 14   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 56   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 52   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 54   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 95   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 17   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 21   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 44               → 7.56 s
#   02. 44 → 14              → 5.20 s
#   03. 14 → 56              → 4.28 s
#   04. 56 → 52              → 5.50 s
#   05. 52 → 54              → 5.92 s
#   06. 54 → 95              → 6.01 s
#   07. 95 → 17              → 3.56 s
#   08. 17 → 21              → 4.71 s
#   09. 21 → O               → 4.51 s
# Tổng thời gian chu kỳ 38: 58.22 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 39: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 33   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   02. Node ID: 53   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   03. Node ID: 62   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   04. Node ID: 59   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 13   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   06. Node ID: 22   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   07. Node ID: 29   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   08. Node ID: 65   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 33               → 8.19 s
#   02. 33 → 53              → 3.56 s
#   03. 53 → 62              → 6.01 s
#   04. 62 → 59              → 5.92 s
#   05. 59 → 13              → 5.50 s
#   06. 13 → 22              → 4.28 s
#   07. 22 → 29              → 5.20 s
#   08. 29 → 65              → 4.93 s
#   09. 65 → O               → 4.51 s
# Tổng thời gian chu kỳ 39: 61.37 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 40: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 42   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 38   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 31   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 9    | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 6    | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 3    | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 96   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 25   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 42               → 7.56 s
#   02. 42 → 38              → 5.20 s
#   03. 38 → 31              → 4.28 s
#   04. 31 → 9               → 5.50 s
#   05. 9 → 6                → 5.92 s
#   06. 6 → 3                → 6.01 s
#   07. 3 → 96               → 3.56 s
#   08. 96 → 25              → 4.71 s
#   09. 25 → O               → 4.51 s
# Tổng thời gian chu kỳ 40: 57.61 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 41: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 68   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 41   | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 94   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 34   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 39   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 23   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 4    | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 66   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 68               → 7.56 s
#   02. 68 → 41              → 5.20 s
#   03. 41 → 94              → 4.28 s
#   04. 94 → 34              → 5.50 s
#   05. 34 → 39              → 5.92 s
#   06. 39 → 23              → 6.01 s
#   07. 23 → 4               → 3.56 s
#   08. 4 → 66               → 4.71 s
#   09. 66 → O               → 4.51 s
# Tổng thời gian chu kỳ 41: 59.46 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 42: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 16   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 1    | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 80   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 76   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 45   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 60   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 30   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 98   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 16               → 7.56 s
#   02. 16 → 1               → 5.20 s
#   03. 1 → 80               → 4.28 s
#   04. 80 → 76              → 5.50 s
#   05. 76 → 45              → 5.92 s
#   06. 45 → 60              → 6.01 s
#   07. 60 → 30              → 3.56 s
#   08. 30 → 98              → 4.71 s
#   09. 98 → O               → 4.51 s
# Tổng thời gian chu kỳ 42: 60.38 s
# Sau cập nhật năng lượng: 100 nodes sống, 0 nodes chết
#
# Chu kỳ 43: 100/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 72   | Vị trí (x,y,z): (15.09, 23.93, 70.10)
#   02. Node ID: 7    | Vị trí (x,y,z): (66.49, 25.48, 77.55)
#   03. Node ID: 55   | Vị trí (x,y,z): (72.84, 19.97, 35.58)
#   04. Node ID: 75   | Vị trí (x,y,z): (86.15, 72.41, 25.89)
#   05. Node ID: 40   | Vị trí (x,y,z): (69.75, 71.21, 82.77)
#   06. Node ID: 43   | Vị trí (x,y,z): (19.96, 81.90, 50.80)
#   07. Node ID: 97   | Vị trí (x,y,z): (27.19, 75.45, 16.50)
#   08. Node ID: 57   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 72               → 7.56 s
#   02. 72 → 7               → 5.20 s
#   03. 7 → 55               → 4.28 s
#   04. 55 → 75              → 5.50 s
#   05. 75 → 40              → 5.92 s
#   06. 40 → 43              → 6.01 s
#   07. 43 → 97              → 3.56 s
#   08. 97 → 57              → 4.71 s
#   09. 57 → O               → 4.51 s
# Tổng thời gian chu kỳ 43: 57.05 s
# Sau cập nhật năng lượng: 94 nodes sống, 6 nodes chết
#
# Chu kỳ 44: 94/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 85   | Vị trí (x,y,z): (21.81, 76.98, 41.23)
#   02. Node ID: 69   | Vị trí (x,y,z): (59.69, 51.73, 81.21)
#   03. Node ID: 49   | Vị trí (x,y,z): (76.38, 79.77, 89.84)
#   04. Node ID: 92   | Vị trí (x,y,z): (83.10, 85.58, 37.48)
#   05. Node ID: 67   | Vị trí (x,y,z): (80.07, 42.52, 24.69)
#   06. Node ID: 11   | Vị trí (x,y,z): (68.90, 16.08, 64.15)
#   07. Node ID: 71   | Vị trí (x,y,z): (16.33, 17.43, 68.98)
#   08. Node ID: 82   | Vị trí (x,y,z): (26.60, 28.70, 22.39)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 85               → 9.00 s
#   02. 85 → 69              → 6.06 s
#   03. 69 → 49              → 3.38 s
#   04. 49 → 92              → 5.31 s
#   05. 92 → 67              → 4.50 s
#   06. 67 → 11              → 4.88 s
#   07. 11 → 71              → 5.28 s
#   08. 71 → 82              → 4.90 s
#   09. 82 → O               → 4.51 s
# Tổng thời gian chu kỳ 44: 62.02 s
# Sau cập nhật năng lượng: 42 nodes sống, 58 nodes chết
#
# Chu kỳ 45: 42/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 79   | Vị trí (x,y,z): (61.28, 18.29, 67.75)
#   02. Node ID: 24   | Vị trí (x,y,z): (79.99, 66.25, 88.60)
#   03. Node ID: 0    | Vị trí (x,y,z): (43.72, 67.38, 76.72)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 79               → 9.32 s
#   02. 79 → 24              → 5.55 s
#   03. 24 → 0               → 3.82 s
#   04. 0 → O                → 11.11 s
# Tổng thời gian chu kỳ 45: 48.62 s
# Sau cập nhật năng lượng: 42 nodes sống, 58 nodes chết
#
# Chu kỳ 46: 42/100 nodes hoạt động
#
# Đường đi tối ưu chi tiết (theo thứ tự thăm của AUV):
#   01. Node ID: 35   | Vị trí (x,y,z): (43.72, 67.38, 76.72)
#   02. Node ID: 99   | Vị trí (x,y,z): (79.99, 66.25, 88.60)
#   03. Node ID: 32   | Vị trí (x,y,z): (61.28, 18.29, 67.75)
# về O(0, 0, 0)
#
# Thời gian từng chặng trong chu kỳ:
#   01. O → 35               → 11.11 s
#   02. 35 → 99              → 3.82 s
#   03. 99 → 32              → 5.55 s
#   04. 32 → O               → 9.32 s
# Tổng thời gian chu kỳ 46: 50.00 s
# Sau cập nhật năng lượng: 6 nodes sống, 94 nodes chết
#
# Mạng sập sau cập nhật: 94/100 nodes chết
#
# Tổng số chu kỳ hoàn thành: 46
# Tổng thời gian di chuyển của AUV: 2725.56 s
